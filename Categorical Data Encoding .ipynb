# %%
import pandas as pd

df=pd.read_csv('Melbourne_housing_dataset_full.csv')

# %%
def determine_feature(df):
    
    feature_types=[]
    n_unique_values_threshold = 5
    
    for column in df.columns:
        unique_values = df[column].unique()
        example_value = unique_values[0]
        
        if (isinstance(example_value, str)) or (len(unique_values)<= n_unique_values_threshold):
           feature_types.append("categorical")
        else:
           feature_types.append("continuous")
    
    return feature_types

# %%
feature_types = determine_feature(df)
i=0
for column in df.columns:
    print(column,"-", feature_types[i])
    i=i+1
# Out:
# Suburb - categorical
# Address - categorical
# Rooms - continuous
# Type - categorical
# Price - continuous
# Method - categorical
# SellerG - categorical
# Date - categorical
# Distance - continuous
# Postcode - continuous
# Bedroom2 - continuous
# Bathroom - continuous
# Car - continuous
# Landsize - continuous
# BuildingArea - continuous
# YearBuilt - continuous
# CouncilArea - categorical
# Lattitude - continuous
# Longtitude - continuous
# Regionname - categorical
# Propertycount - continuous

# %%
new_CouncilArea=pd.get_dummies(df.CouncilArea)
new_Regionname =pd.get_dummies(df.Regionname)

# %%
new_CouncilArea.head()
# Out:
#    Banyule City Council  Bayside City Council  Boroondara City Council  \
# 0                     0                     0                        0
# 1                     0                     0                        0
# 2                     0                     0                        0
# 3                     0                     0                        0
# 4                     0                     0                        0
#
#    Brimbank City Council  Cardinia Shire Council  Casey City Council  \
# 0                      0                       0                   0
# 1                      0                       0                   0
# 2                      0                       0                   0
# 3                      0                       0                   0
# 4                      0                       0                   0
#
#    Darebin City Council  Frankston City Council  Glen Eira City Council  \
# ...

# %%
new_Regionname.head()
# Out:
#    Eastern Metropolitan  Eastern Victoria  Northern Metropolitan  \
# 0                     0                 0                      1
# 1                     0                 0                      1
# 2                     0                 0                      1
# 3                     0                 0                      1
# 4                     0                 0                      1
#
#    Northern Victoria  South-Eastern Metropolitan  Southern Metropolitan  \
# 0                  0                           0                      0
# 1                  0                           0                      0
# 2                  0                           0                      0
# 3                  0                           0                      0
# 4                  0                           0                      0
#
#    Western Metropolitan  Western Victoria
# 0                     0                 0
# 1                     0                 0
# ...

# %%
merged = pd.concat([df,new_CouncilArea,new_Regionname],axis='columns')
merged.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Yarra City Council  \
# 0  3/09/2016       2.5    3067.0  ...                   1
# 1  3/12/2016       2.5    3067.0  ...                   1
# 2  4/02/2016       2.5    3067.0  ...                   1
# 3  4/02/2016       2.5    3067.0  ...                   1
# 4  4/03/2017       2.5    3067.0  ...                   1
#
#    Yarra Ranges Shire Council  Eastern Metropolitan  Eastern Victoria  \
# 0                           0                     0                 0
# ...

# %%
final = merged.drop(['CouncilArea','Regionname','Banyule City Council','Eastern Metropolitan'],axis='columns') #to remove redundancy and dummy variables
final.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Wyndham City Council  \
# 0  3/09/2016       2.5    3067.0  ...                     0
# 1  3/12/2016       2.5    3067.0  ...                     0
# 2  4/02/2016       2.5    3067.0  ...                     0
# 3  4/02/2016       2.5    3067.0  ...                     0
# 4  4/03/2017       2.5    3067.0  ...                     0
#
#    Yarra City Council  Yarra Ranges Shire Council  Eastern Victoria  \
# 0                   1                           0                 0
# ...

# %%
final.to_csv('encoded.csv', index=False)
